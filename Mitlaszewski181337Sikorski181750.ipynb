# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/cifar10.zip -d /content/
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
#   inflating: /content/cifar10/cifar10/train/truck/0001.png
#   inflating: /content/cifar10/cifar10/train/truck/0002.png
#   inflating: /content/cifar10/cifar10/train/truck/0003.png
#   inflating: /content/cifar10/cifar10/train/truck/0004.png
#   inflating: /content/cifar10/cifar10/train/truck/0005.png
#   inflating: /content/cifar10/cifar10/train/truck/0006.png
#   inflating: /content/cifar10/cifar10/train/truck/0007.png
#   inflating: /content/cifar10/cifar10/train/truck/0008.png
#   inflating: /content/cifar10/cifar10/train/truck/0009.png
#   inflating: /content/cifar10/cifar10/train/truck/0010.png
#   inflating: /content/cifar10/cifar10/train/truck/0011.png
#   inflating: /content/cifar10/cifar10/train/truck/0012.png
#   inflating: /content/cifar10/cifar10/train/truck/0013.png
#   inflating: /content/cifar10/cifar10/train/truck/0014.png
#   inflating: /content/cifar10/cifar10/train/truck/0015.png
# ...

# %%
# !git clone https://github.com/SHI-Labs/Convolutional-MLPs.git
# Out:
# Cloning into 'Convolutional-MLPs'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 139 (delta 66), reused 110 (delta 47), pack-reused 0
# Receiving objects: 100% (139/139), 1.78 MiB | 4.46 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
# %cd Convolutional-MLPs/
# Out:
# [Errno 2] No such file or directory: 'Convolutional-MLPs/'
# /content

# %%
# !pwd
# Out:
# /content

# %%
# !pip install torch torchvision torchaudio
# !pip install timm
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
import torch
import torch.nn as nn
import torchvision.utils
import torch.distributed as dist
from torch.nn.parallel import DistributedDataParallel as NativeDDP

# %%
print(torch.__version__)
# Out:
# 2.3.0+cu121

# %%
# !whereis torchrun
# Out:
# torchrun: /usr/local/bin/torchrun

# %%
#nie trzeba uzywac shell skryptu, wystarczy uzyc py3 classifcaiton.py
# !python3 Convolutional-MLPs/classification.py -c Convolutional-MLPs/configs/classification/finetuned/convmlp_s_cifar10.yml /content/cifar10/cifar10
# -c Convolutional-MLPs/configs/classification/finetuned/convmlp_s_cifar10.yml Convolutional-MLPs/cifar10/cifar10/
# Out:
# Training with a single process on 1 GPUs.
# Model convmlp_s_classification created, param count:9565674
# Data processing configuration for current model + dataset:
# 	input_size: (3, 32, 32)
# 	interpolation: bicubic
# 	mean: (0.4914, 0.4822, 0.4465)
# 	std: (0.247, 0.2435, 0.2616)
# 	crop_pct: 1.0
# 	crop_mode: center
# Using native Torch AMP. Training in mixed precision.
# Scheduled epochs: 60
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...
